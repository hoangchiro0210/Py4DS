# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
diamonds_url = 'https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv'

# %%
diamonds_df = pd.read_csv(diamonds_url)

# %%
diamonds_df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds_df['price_per_carat'] = diamonds_df['price']/diamonds_df['carat']

# %%
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    price_per_carat
# 0      1417.391304
# 1      1552.380952
# 2      1421.739130
# 3      1151.724138
# 4      1080.645161

# %%
diamonds_df['price_per_carat_is_high'] = np.where(diamonds_df['price_per_carat']>3500,1,0)
diamonds_df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        price_per_carat  price_per_carat_is_high
# 53935      3829.166667                        1
# 53936      3829.166667                        1
# 53937      3938.571429                        1
# 53938      3205.813953                        0
# 53939      3676.000000                        1

# %%
diamonds_df['price']= diamonds_df['price']*1.3
diamonds_df
# Out:
#        carat        cut color clarity  depth  table    price     x     y  \
# 0       0.23      Ideal     E     SI2   61.5   55.0   550.94  3.95  3.98
# 1       0.21    Premium     E     SI1   59.8   61.0   550.94  3.89  3.84
# 2       0.23       Good     E     VS1   56.9   65.0   552.63  4.05  4.07
# 3       0.29    Premium     I     VS2   62.4   58.0   564.46  4.20  4.23
# 4       0.31       Good     J     SI2   63.3   58.0   566.15  4.34  4.35
# ...      ...        ...   ...     ...    ...    ...      ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  4659.33  5.75  5.76
# 53936   0.72       Good     D     SI1   63.1   55.0  4659.33  5.69  5.75
# 53937   0.70  Very Good     D     SI1   62.8   60.0  4659.33  5.66  5.68
# 53938   0.86    Premium     H     SI2   61.0   58.0  4659.33  6.15  6.12
# 53939   0.75      Ideal     D     SI2   62.2   55.0  4659.33  5.83  5.87
#
#           z  price_per_carat  price_per_carat_is_high
# 0      2.43      1417.391304                        0
# 1      2.31      1552.380952                        0
# 2      2.31      1421.739130                        0
# 3      2.63      1151.724138                        0
# 4      2.75      1080.645161                        0
# ...     ...              ...                      ...
# 53935  3.50      3829.166667                        1
# 53936  3.61      3829.166667                        1
# 53937  3.56      3938.571429                        1
# 53938  3.74      3205.813953                        0
# 53939  3.64      3676.000000                        1
#
# [53940 rows x 12 columns]

# %%
import math
diamonds_df['rounded_price']=diamonds_df['price'].apply(math.ceil)
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table   price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  550.94  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  550.94  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  552.63  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  564.46  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  566.15  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high  rounded_price
# 0      1417.391304                        0            551
# 1      1552.380952                        0            551
# 2      1421.739130                        0            553
# 3      1151.724138                        0            565
# 4      1080.645161                        0            567

# %%
diamonds_df['rounded_price_to_100multiple']=diamonds_df['price'].apply(lambda x: math.ceil(x/100)*100)
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table   price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  550.94  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  550.94  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  552.63  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  564.46  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  566.15  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high  rounded_price  \
# 0      1417.391304                        0            551
# 1      1552.380952                        0            551
# 2      1421.739130                        0            553
# 3      1151.724138                        0            565
# 4      1080.645161                        0            567
#
#    rounded_price_to_100multiple
# 0                           600
# 1                           600
# 2                           600
# 3                           600
# 4                           600

# %%
def get_100_multiple_ceil(x):
 y = math.ceil(x/100)*100
 return y

# %%
diamonds_df['rounded_price_to_100multiple']=diamonds_df['price'].apply(get_100_multiple_ceil)
diamonds_df.head()
# Out:
#    carat      cut color clarity  depth  table   price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0  550.94  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0  550.94  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0  552.63  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0  564.46  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0  566.15  4.34  4.35  2.75
#
#    price_per_carat  price_per_carat_is_high  rounded_price  \
# 0      1417.391304                        0            551
# 1      1552.380952                        0            551
# 2      1421.739130                        0            553
# 3      1151.724138                        0            565
# 4      1080.645161                        0            567
#
#    rounded_price_to_100multiple
# 0                           600
# 1                           600
# 2                           600
# 3                           600
# 4                           600

# %%
diamonds_low_df = diamonds_df.loc[diamonds_df['cut']=='Ideal']
diamonds_low_df.head()
pd.set_option('display.max_columns',100)
pd.set_option('display.max_rows',100)

# %%
carat1 = diamonds_df.loc[diamonds_df['carat']>1]
carat1.count()
# Out:
# carat      17502
# cut        17502
# color      17502
# clarity    17502
# depth      17502
# table      17502
# price      17502
# x          17502
# y          17502
# z          17502
# dtype: int64

# %%
diamonds_df.hist(column='carat')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AC70FCBA00>]],
#       dtype=object)

# %%
diamonds_df.hist(column='carat', bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000022DA121F370>]],
#       dtype=object)

# %%
sns.distplot(diamonds_df['carat'])

# %%
sns.distplot(diamonds_df.carat, kde = False )

# %%
sns.distplot(diamonds_df.carat, kde=False, bins=100)

# %%
import numpy as np
sns.distplot(np.log(diamonds_df.price), kde=False)

# %%
diamonds_df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
diamonds_df.price.nunique()
# Out:
# 11602

# %%
cut_count_table = pd.crosstab(index=diamonds_df['cut'],columns='count')
cut_count_table
# Out:
# col_0      count
# cut
# Fair        1610
# Good        4906
# Ideal      21551
# Premium    13791
# Very Good  12082

# %%
cut_count_table.plot(kind = 'bar')

# %%
sns.catplot("cut", data=diamonds_df, aspect=1.5, kind="count",
color="g")

# %%
import seaborn as sns
from numpy import median, mean
sns.set(style="whitegrid")
ax = sns.barplot(x="cut", y="price", data=diamonds_df,estimator=median)

# %%
sns.set(style="whitegrid")
ax = sns.barplot(x="price", y="carat", data=diamonds_df,estimator=mean)

# %%
sns.set(style="whitegrid")
ax = sns.barplot(x="cut", y="price", data=diamonds_df,estimator = mean)

# %%
ax = sns.barplot(x="cut", y="price", data=diamonds_df, estimator=mean, ci=68, order=['Ideal','Good','Very Good','Fair','Premium'])

# %%
ax = sns.barplot(x="cut", y="price", data=diamonds_df, estimator=mean, ci=95, order=['Ideal','Good','Very Good','Fair','Premium'])

# %%
ax = sns.barplot(x="cut", y="price", hue='color', data=diamonds_df)

# %%
ax = sns.barplot(x='cut', y='price', hue='clarity', data=diamonds_df)
ax.legend(loc='lower right',ncol= 5)

# %%
ax = sns.barplot(x='cut', y='price', hue='color', data=diamonds_df)
ax.legend(loc='upper right', ncol=4)
ax.set_xlabel('Cut', fontdict={'fontsize' : 1.5})
ax.set_ylabel('Price', fontdict={'fontsize' : 1.5})

# %%
# get records in the DataFrame corresponding to ideal cut
ideal_group = diamonds_df.loc[diamonds_df['cut']=='Ideal']
# get the location of x coordinate where the annotation has to be

x = ideal_group.index.tolist()

# %%
x
# Out:
# [0,
#  11,
#  13,
#  16,
#  39,
#  40,
#  41,
#  51,
#  52,
#  55,
#  60,
#  62,
#  63,
#  65,
#  66,
#  82,
#  83,
#  90,
#  92,
#  102,
#  104,
#  105,
#  107,
#  108,
#  109,
#  110,
#  111,
#  114,
#  115,
#  117,
#  118,
#  119,
#  120,
#  121,
#  130,
#  132,
#  138,
#  139,
#  144,
#  149,
#  151,
#  155,
#  156,
#  159,
#  163,
#  164,
#  167,
#  168,
#  170,
#  173,
#  174,
#  179,
#  180,
#  181,
#  182,
#  183,
#  185,
#  191,
#  198,
#  207,
#  209,
#  212,
#  213,
#  214,
#  216,
#  217,
#  220,
#  224,
#  229,
#  233,
#  234,
#  237,
#  240,
#  248,
#  249,
#  250,
#  256,
#  258,
#  262,
#  265,
#  269,
#  273,
#  274,
#  278,
#  291,
#  292,
#  293,
#  294,
#  295,
#  300,
#  302,
#  303,
#  308,
#  309,
#  312,
#  313,
#  315,
#  316,
#  318,
#  326,
#  331,
#  332,
#  341,
#  346,
#  348,
#  349,
#  350,
#  351,
#  355,
#  358,
#  363,
#  371,
#  379,
#  392,
#  395,
#  401,
#  404,
#  408,
#  409,
#  410,
#  411,
#  412,
#  413,
#  414,
#  417,
#  418,
#  419,
#  422,
#  425,
#  430,
#  435,
#  436,
#  437,
#  438,
#  446,
#  449,
#  450,
#  452,
#  453,
#  455,
#  458,
#  460,
#  467,
#  468,
#  474,
#  477,
#  478,
#  480,
#  492,
#  493,
#  494,
#  498,
#  500,
#  503,
#  505,
#  506,
#  509,
#  513,
#  515,
#  517,
#  519,
#  535,
#  539,
#  540,
#  541,
#  545,
#  546,
#  551,
#  552,
#  553,
#  554,
#  557,
#  558,
#  560,
#  565,
#  571,
#  572,
#  573,
#  574,
#  575,
#  576,
#  578,
#  579,
#  582,
#  583,
#  584,
#  585,
#  586,
#  587,
#  592,
#  593,
#  606,
#  607,
#  608,
#  612,
#  613,
#  614,
#  615,
#  622,
#  624,
#  630,
#  631,
#  633,
#  636,
#  639,
#  646,
#  648,
#  649,
#  650,
#  653,
#  655,
#  660,
#  662,
#  665,
#  666,
#  672,
#  675,
#  680,
#  681,
#  684,
#  687,
#  689,
#  690,
#  691,
#  695,
#  715,
#  716,
#  717,
#  718,
#  720,
#  721,
#  722,
#  728,
#  730,
#  731,
#  732,
#  733,
#  734,
#  735,
#  736,
#  737,
#  738,
#  742,
#  746,
#  747,
#  755,
#  758,
#  766,
#  767,
#  772,
#  775,
#  781,
#  783,
#  785,
#  786,
#  796,
#  804,
#  810,
#  817,
#  819,
#  820,
#  825,
#  826,
#  829,
#  830,
#  833,
#  834,
#  835,
#  836,
#  838,
#  840,
#  841,
#  845,
#  846,
#  847,
#  848,
#  850,
#  852,
#  853,
#  854,
#  855,
#  861,
#  862,
#  865,
#  867,
#  869,
#  870,
#  873,
#  877,
#  878,
#  891,
#  892,
#  893,
#  896,
#  903,
#  904,
#  910,
#  911,
#  916,
#  917,
#  918,
#  920,
#  923,
#  927,
#  931,
#  937,
#  940,
#  941,
#  944,
#  950,
#  951,
#  952,
#  955,
#  956,
#  959,
#  961,
#  962,
#  963,
#  964,
#  966,
#  970,
#  971,
#  973,
#  978,
#  979,
#  982,
#  986,
#  987,
#  988,
#  989,
#  992,
#  995,
#  996,
#  1000,
#  1001,
#  1003,
#  1004,
#  1005,
#  1006,
#  1007,
#  1008,
#  1013,
#  1015,
#  1017,
#  1018,
#  1022,
#  1023,
#  1029,
#  1035,
#  1040,
#  1042,
#  1043,
#  1044,
#  1045,
#  1046,
#  1047,
#  1048,
#  1049,
#  1050,
#  1051,
#  1052,
#  1063,
#  1064,
#  1065,
#  1067,
#  1078,
#  1081,
#  1084,
#  1085,
#  1086,
#  1089,
#  1090,
#  1104,
#  1108,
#  1110,
#  1114,
#  1116,
#  1118,
#  1119,
#  1122,
#  1123,
#  1129,
#  1130,
#  1132,
#  1134,
#  1139,
#  1144,
#  1145,
#  1151,
#  1152,
#  1153,
#  1154,
#  1157,
#  1161,
#  1162,
#  1168,
#  1174,
#  1175,
#  1178,
#  1179,
#  1180,
#  1181,
#  1184,
#  1187,
#  1194,
#  1197,
#  1203,
#  1204,
#  1205,
#  1211,
#  1216,
#  1217,
#  1218,
#  1219,
#  1221,
#  1226,
#  1229,
#  1230,
#  1236,
#  1239,
#  1240,
#  1242,
#  1249,
#  1250,
#  1251,
#  1252,
#  1254,
#  1255,
#  1257,
#  1258,
#  1259,
#  1260,
#  1261,
#  1264,
#  1265,
#  1269,
#  1272,
#  1273,
#  1274,
#  1277,
#  1279,
#  1281,
#  1282,
#  1283,
#  1288,
#  1289,
#  1290,
#  1291,
#  1292,
#  1293,
#  1299,
#  1302,
#  1304,
#  1311,
#  1314,
#  1315,
#  1316,
#  1317,
#  1323,
#  1328,
#  1329,
#  1330,
#  1331,
#  1333,
#  1335,
#  1339,
#  1340,
#  1341,
#  1345,
#  1346,
#  1347,
#  1349,
#  1356,
#  1365,
#  1366,
#  1367,
#  1368,
#  1369,
#  1370,
#  1373,
#  1374,
#  1375,
#  1379,
#  1382,
#  1387,
#  1388,
#  1389,
#  1390,
#  1391,
#  1392,
#  1393,
#  1394,
#  1395,
#  1396,
#  1397,
#  1398,
#  1399,
#  1400,
#  1405,
#  1406,
#  1407,
#  1409,
#  1415,
#  1416,
#  1421,
#  1425,
#  1426,
#  1430,
#  1431,
#  1432,
#  1435,
#  1436,
#  1439,
#  1443,
#  1445,
#  1447,
#  1448,
#  1449,
#  1451,
#  1453,
#  1454,
#  1455,
#  1456,
#  1457,
#  1458,
#  1459,
#  1461,
#  1464,
#  1466,
#  1468,
#  1470,
#  1473,
#  1477,
#  1480,
#  1481,
#  1482,
#  1483,
#  1484,
#  1488,
#  1489,
#  1494,
#  1495,
#  1497,
#  1502,
#  1503,
#  1504,
#  1505,
#  1513,
#  1514,
#  1517,
#  1518,
#  1519,
#  1520,
#  1521,
#  1522,
#  1529,
#  1534,
#  1538,
#  1543,
#  1550,
#  1553,
#  1557,
#  1558,
#  1559,
#  1560,
#  1561,
#  1564,
#  1566,
#  1567,
#  1573,
#  1574,
#  1576,
#  1577,
#  1578,
#  1579,
#  1580,
#  1581,
#  1584,
#  1585,
#  1591,
#  1593,
#  1594,
#  1600,
#  1601,
#  1602,
#  1603,
#  1604,
#  1605,
#  1606,
#  1607,
#  1610,
#  1611,
#  1612,
#  1613,
#  1617,
#  1618,
#  1619,
#  1621,
#  1622,
#  1628,
#  1629,
#  1632,
#  1634,
#  1636,
#  1640,
#  1646,
#  1647,
#  1654,
#  1656,
#  1657,
#  1672,
#  1673,
#  1674,
#  1680,
#  1681,
#  1686,
#  1688,
#  1689,
#  1690,
#  1696,
#  1698,
#  1700,
#  1701,
#  1702,
#  1703,
#  1705,
#  1707,
#  1708,
#  1714,
#  1720,
#  1721,
#  1722,
#  1728,
#  1732,
#  1737,
#  1738,
#  1739,
#  1740,
#  1741,
#  1742,
#  1743,
#  1748,
#  1749,
#  1750,
#  1752,
#  1755,
#  1757,
#  1763,
#  1764,
#  1771,
#  1775,
#  1778,
#  1781,
#  1782,
#  1783,
#  1786,
#  1787,
#  1789,
#  1793,
#  1799,
#  1800,
#  1801,
#  1802,
#  1806,
#  1814,
#  1815,
#  1816,
#  1819,
#  1835,
#  1839,
#  1849,
#  1850,
#  1851,
#  1853,
#  1854,
#  1856,
#  1857,
#  1858,
#  1859,
#  1860,
#  1863,
#  1865,
#  1871,
#  1875,
#  1876,
#  1877,
#  1883,
#  1889,
#  1890,
#  1891,
#  1892,
#  1895,
#  1901,
#  1905,
#  1910,
#  1911,
#  1913,
#  1914,
#  1915,
#  1918,
#  1919,
#  1924,
#  1933,
#  1934,
#  1935,
#  1944,
#  1948,
#  1951,
#  1956,
#  1957,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1967,
#  1968,
#  1969,
#  1970,
#  1972,
#  1978,
#  1979,
#  1981,
#  1982,
#  1983,
#  1984,
#  1993,
#  1995,
#  1996,
#  1999,
#  2001,
#  2002,
#  2003,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2017,
#  2019,
#  2020,
#  2026,
#  2031,
#  2035,
#  2038,
#  2041,
#  2042,
#  2046,
#  2048,
#  2059,
#  2067,
#  2075,
#  2080,
#  2084,
#  2090,
#  2093,
#  2096,
#  2097,
#  2099,
#  2107,
#  2110,
#  2113,
#  2115,
#  2116,
#  2120,
#  2122,
#  2127,
#  2129,
#  2130,
#  2133,
#  2134,
#  2135,
#  2136,
#  2137,
#  2139,
#  2141,
#  2144,
#  2147,
#  2148,
#  2152,
#  2153,
#  2155,
#  2156,
#  2158,
#  2160,
#  2161,
#  2162,
#  2163,
#  2166,
#  2167,
#  2168,
#  2171,
#  2172,
#  2173,
#  2179,
#  2181,
#  2185,
#  2186,
#  2188,
#  2189,
#  2198,
#  2199,
#  2200,
#  2201,
#  2203,
#  2208,
#  2210,
#  2214,
#  2222,
#  2223,
#  2224,
#  2225,
#  2231,
#  2235,
#  2238,
#  2239,
#  2241,
#  2243,
#  2246,
#  2253,
#  2255,
#  2257,
#  2260,
#  2261,
#  2267,
#  2268,
#  2269,
#  2270,
#  2271,
#  2273,
#  2275,
#  2277,
#  2280,
#  2281,
#  2288,
#  2291,
#  2293,
#  2295,
#  2301,
#  2305,
#  2306,
#  2307,
#  2309,
#  2315,
#  2316,
#  2317,
#  2318,
#  2319,
#  2320,
#  2324,
#  2325,
#  2327,
#  2328,
#  2331,
#  2332,
#  2333,
#  2335,
#  2337,
#  2338,
#  2339,
#  2341,
#  2342,
#  2343,
#  2344,
#  2345,
#  2346,
#  2348,
#  2349,
#  2350,
#  2355,
#  2359,
#  2360,
#  2369,
#  2370,
#  2372,
#  2373,
#  2374,
#  2389,
#  2390,
#  2391,
#  2392,
#  2393,
#  2395,
#  2399,
#  2400,
#  2401,
#  2403,
#  2405,
#  2406,
#  2407,
#  2408,
#  2409,
#  2415,
#  2416,
#  2417,
#  2423,
#  2424,
#  2426,
#  2428,
#  2429,
#  2430,
#  2433,
#  2434,
#  2437,
#  2438,
#  2439,
#  2440,
#  2441,
#  2449,
#  2451,
#  2452,
#  2453,
#  2454,
#  2455,
#  2457,
#  2461,
#  2462,
#  2463,
#  2464,
#  2465,
#  2466,
#  2467,
#  2468,
#  2471,
#  2472,
#  2478,
#  2485,
#  2486,
#  2487,
#  2491,
#  2493,
#  2495,
#  2499,
#  2500,
#  2501,
#  2502,
#  2505,
#  2506,
#  2508,
#  2509,
#  2512,
#  2513,
#  2515,
#  2516,
#  2517,
#  2518,
#  2519,
#  2525,
#  2529,
#  2530,
#  2541,
#  2543,
#  2544,
#  2545,
#  2548,
#  2549,
#  2557,
#  2558,
#  2559,
#  2561,
#  2562,
#  2570,
#  2573,
#  2574,
#  2575,
#  2576,
#  2577,
#  2579,
#  2582,
#  2586,
#  2589,
#  2593,
#  2594,
#  2596,
#  2599,
#  2604,
#  2605,
#  2609,
#  2612,
#  2613,
#  2614,
#  2621,
#  2626,
#  2627,
#  2629,
#  2633,
#  2634,
#  2635,
#  2636,
#  2637,
#  2641,
#  2644,
#  2647,
#  2650,
#  2652,
#  2653,
#  2655,
#  2660,
#  2662,
#  ...]
